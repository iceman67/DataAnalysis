# %%
import pandas as pd

# %%
df=pd.read_csv('지하철유무임승차.csv')
df
# Out:
#           사용월  호선명       지하철역  유임승차인원  무임승차인원  유임하차인원  무임하차인원      작업일자
# 0      202009  1호선        서울역  724320  137054  711203  128369  20201003
# 1      202009  1호선        동대문  184244   94355  184462   95369  20201003
# 2      202009  1호선        제기동  202713  246990  199630  268967  20201003
# 3      202009  1호선        신설동  226849   92148  227364   88012  20201003
# 4      202009  1호선         시청  376545   50389  376445   47503  20201003
# ...       ...  ...        ...     ...     ...     ...     ...       ...
# 46677  201501  9호선        구반포   80815   87864   21595   22556  20150206
# 46678  201501  9호선         동작   40212   26443   11720    9980  20150206
# 46679  201501  9호선  흑석(중앙대입구)  252588  260917   54505   56150  20150206
# 46680  201501  9호선         노들  121496  100670   27470   25964  20150206
# 46681  201501  9호선        노량진  817907  864989  114416  119275  20150206
#
# [46682 rows x 8 columns]

# %%
len(df)
# Out:
# 46682

# %%
df.columns
# Out:
# Index(['사용월', '호선명', '지하철역', '유임승차인원', '무임승차인원', '유임하차인원', '무임하차인원', '작업일자'], dtype='object')

# %%
df0=df[['사용월', '호선명','지하철역', '무임승차인원','무임하차인원']]

# %%
df0
# Out:
#           사용월  호선명       지하철역  무임승차인원  무임하차인원
# 0      202009  1호선        서울역  137054  128369
# 1      202009  1호선        동대문   94355   95369
# 2      202009  1호선        제기동  246990  268967
# 3      202009  1호선        신설동   92148   88012
# 4      202009  1호선         시청   50389   47503
# ...       ...  ...        ...     ...     ...
# 46677  201501  9호선        구반포   87864   22556
# 46678  201501  9호선         동작   26443    9980
# 46679  201501  9호선  흑석(중앙대입구)  260917   56150
# 46680  201501  9호선         노들  100670   25964
# 46681  201501  9호선        노량진  864989  119275
#
# [46682 rows x 5 columns]

# %%
len(df0)
# Out:
# 46682

# %%
import numpy as np

# %%
x = np.array(df0)

# %%
print(x)
# Out:
# [[202009 '1호선' '서울역' 137054 128369]
#  [202009 '1호선' '동대문' 94355 95369]
#  [202009 '1호선' '제기동' 246990 268967]
#  ...
#  [201501 '9호선' '흑석(중앙대입구)' 260917 56150]
#  [201501 '9호선' '노들' 100670 25964]
#  [201501 '9호선' '노량진' 864989 119275]]

# %%
df2=df['무임승차인원']

# %%
df2
# Out:
# 0        137054
# 1         94355
# 2        246990
# 3         92148
# 4         50389
#           ...
# 46677     87864
# 46678     26443
# 46679    260917
# 46680    100670
# 46681    864989
# Name: 무임승차인원, Length: 46682, dtype: int64

# %%
y=np.array(df2)

# %%
print(y)
# Out:
# [137054  94355 246990 ... 260917 100670 864989]

# %%
np.mean(y)
# Out:
# 88504.99096011311

# %%
op=pd.read_csv('노인인구증가.csv')
op
# Out:
#        Column1 Column2   Column3    Column4    Column5 Column6   Column7  \
# 0   행정구역별(읍면동)     연령별      2015       2015       2015    2015      2015
# 1   행정구역별(읍면동)     연령별    총인구(명)  총인구_남자(명)  총인구_여자(명)  총인구_성비    내국인(명)
# 2           전국      합계  51069375   25608502   25460873   100.6  49705663
# 3           전국    0~4세   2258670    1159011    1099659   105.4   2235397
# 4           전국    5~9세   2267851    1169770    1098081   106.5   2252950
# 5           전국  10~14세   2427792    1262770    1165022   108.4   2418360
# 6           전국  15~19세   3194079    1668683    1525396   109.4   3170545
# 7           전국  20~24세   3531108    1887776    1643332   114.9   3385936
# 8           전국  25~29세   3265288    1728888    1536400   112.5   3027896
# 9           전국  30~34세   3811610    1986796    1824814   108.9   3611034
# 10          전국  35~39세   3926862    2022466    1904396   106.2   3783589
# 11          전국  40~44세   4338827    2218442    2120385   104.6   4215921
# ...

# %%
op1=op[op['Column2']=='65세이상']
op1
# Out:
#    Column1 Column2  Column3  Column4  Column5 Column6  Column7  Column8  \
# 27      전국   65세이상  6617378  2784775  3832603    72.7  6569082  2763407
#
#     Column9 Column10  ... Column33 Column34 Column35 Column36 Column37  \
# 27  3805675     72.6  ...  4231870     74.7  7816991  3364751  4452240
#
#    Column38 Column39 Column40 Column41 Column42
# 27     75.6  7745563  3333575  4411988     75.6
#
# [1 rows x 42 columns]

# %%
op2=op1[['Column7','Column15','Column23','Column31','Column39']]
op2
# Out:
#     Column7 Column15 Column23 Column31 Column39
# 27  6569082  6775118  7115366  7394115  7745563

# %%
op2.rename(columns={'Column7':'2015','Column15':'2016',
                   'Column23':'2017','Column31':'2018',
                   'Column39':'2019'},inplace=True)
# Out:
# C:\Users\sang9\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
op2
# Out:
#        2015     2016     2017     2018     2019
# 27  6569082  6775118  7115366  7394115  7745563

# %%
op2.reset_index()
# Out:
#    index     2015     2016     2017     2018     2019
# 0     27  6569082  6775118  7115366  7394115  7745563

# %%
op3=pd.DataFrame(data=[['2015',6569082],['2016',6775118],['2017',7115366],
                       ['2018',7394115],['2019',7745563]],index=['1','2','3','4','5'],
                columns=['년도','인구수'])
op3
# Out:
#      년도      인구수
# 1  2015  6569082
# 2  2016  6775118
# 3  2017  7115366
# 4  2018  7394115
# 5  2019  7745563

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager, rc

import matplotlib

font_location='c:/Windows/fonts/gulim.ttc' 

font_name=font_manager.FontProperties(fname=font_location).get_name()

matplotlib.rc('font',family=font_name)

# %%
plt.figure(figsize=(12,8))
plt.bar(op3['년도'],op3['인구수'])
plt.xticks(rotation=45, size=20)
plt.yticks(size=20)
plt.xlabel('년도',size=20)
plt.ylabel('인구 수',size=20)
plt.title('2015-2019 노인 인구 수 ',size=30)
plt.grid(alpha=0.5)

# %%
plt.figure(figsize=(12,8))
plt.plot(op3['년도'],op3['인구수'])
plt.xticks(rotation=45, size=20)
plt.yticks(size=20)
plt.xlabel('년도',size=20)
plt.ylabel('인구 수',size=20)
plt.title('2015-2019 노인 인구 수 ',size=30)
plt.grid(alpha=0.5)

# %%
df.shape
# Out:
# (46682, 8)

# %%
df.dtypes
# Out:
# 사용월        int64
# 호선명       object
# 지하철역      object
# 유임승차인원     int64
# 무임승차인원     int64
# 유임하차인원     int64
# 무임하차인원     int64
# 작업일자       int64
# dtype: object

# %%
df.loc[:,'사용월'] = df['사용월'].astype(str)
df.dtypes
# Out:
# 사용월       object
# 호선명       object
# 지하철역      object
# 유임승차인원     int64
# 무임승차인원     int64
# 유임하차인원     int64
# 무임하차인원     int64
# 작업일자       int64
# dtype: object

# %%
tw=df[df['사용월'].str.contains('2020')]
tw
# Out:
#          사용월  호선명 지하철역  유임승차인원  무임승차인원  유임하차인원  무임하차인원      작업일자
# 0     202009  1호선  서울역  724320  137054  711203  128369  20201003
# 1     202009  1호선  동대문  184244   94355  184462   95369  20201003
# 2     202009  1호선  제기동  202713  246990  199630  268967  20201003
# 3     202009  1호선  신설동  226849   92148  227364   88012  20201003
# 4     202009  1호선   시청  376545   50389  376445   47503  20201003
# ...      ...  ...  ...     ...     ...     ...     ...       ...
# 5380  202001  중앙선   망우  163129   69389  156790   70549  20200203
# 5381  202001  중앙선   구리  319613   83155  328109   83657  20200203
# 5382  202001  중앙선   오빈    5191    3541    5269    3529  20200203
# 5383  202001  중앙선   양수   38060   17189   38112   17423  20200203
# 5384  202001  중앙선   덕소  128441   49795  125421   49459  20200203
#
# [5385 rows x 8 columns]

# %%
twm=tw['무임승차인원']
twm.mean()
# Out:
# 43928.27688022284

# %%
nin=df[df['사용월'].str.contains('2019')]
nin
ninm=nin['무임승차인원']
ninm.mean()
# Out:
# 61888.408988273

# %%
eig=df[df['사용월'].str.contains('2018')]
eig
eigm=eig['무임승차인원']
eigm.mean()
# Out:
# 59280.04252543699

# %%
sev=df[df['사용월'].str.contains('2017')]
sev
sevm=sev['무임승차인원']
sevm.mean()
# Out:
# 59456.698926291356

# %%
six=df[df['사용월'].str.contains('2016')]
six
sixm=six['무임승차인원']
sixm.mean()
# Out:
# 59143.760747901295

# %%
fiv=df[df['사용월'].str.contains('2015')]
fiv
fivm=fiv['무임승차인원']
fivm.mean()
# Out:
# 333365.5066045066

# %%
muim=pd.DataFrame(data=[['2015',333365],['2016',59143],['2017',59456],
                       ['2018',59280],['2019',61888],['2020',43928]],index=['1','2','3','4','5','6'],
                columns=['년도','무임 승차 수 '])
muim
# Out:
#      년도  무임 승차 수
# 1  2015    333365
# 2  2016     59143
# 3  2017     59456
# 4  2018     59280
# 5  2019     61888
# 6  2020     43928

# %%
plt.figure(figsize=(12,8))
plt.plot(muim['년도'],muim['무임 승차 수 '])
plt.xticks(rotation=45, size=20)
plt.yticks(size=20)
plt.xlabel('년도',size=20)
plt.ylabel('무임 승차 수',size=20)
plt.title('2015-2019 무임 승차 수 ',size=30)
plt.grid(alpha=0.5)

# %%
muim2=pd.DataFrame(data=[['2016',59143],['2017',59456],
                       ['2018',59280],['2019',61888],['2020',43928]],index=['1','2','3','4','5'],
                columns=['년도','무임 승차 수 '])
muim2
# Out:
#      년도  무임 승차 수
# 1  2016     59143
# 2  2017     59456
# 3  2018     59280
# 4  2019     61888
# 5  2020     43928

# %%
plt.figure(figsize=(12,8))
plt.plot(muim2['년도'],muim2['무임 승차 수 '])
plt.xticks(rotation=45, size=20)
plt.yticks(size=20)
plt.xlabel('년도',size=20)
plt.ylabel('무임 승차 수',size=20)
plt.title('2016-2019 무임 승차 수 ',size=30)
plt.grid(alpha=0.5)

# %%
plt.figure(figsize=(12,8))
plt.plot(muim['년도'],muim['무임 승차 수 '])
plt.plot(op3['년도'],op3['인구수'])
plt.xticks(rotation=45, size=20)
plt.yticks(size=20)
plt.xlabel('년도',size=20)
plt.ylabel('무임 승차 수',size=20)
plt.title('노인인구증가에 따른 무임승차 수 ',size=30)
plt.grid(alpha=0.5)
plt.legend(['무임승차수','노인인구수'],fontsize=20)

# %%
first=df[['사용월','호선명','무임승차인원']]

# %%
first
# Out:
#           사용월  호선명  무임승차인원
# 0      202009  1호선  137054
# 1      202009  1호선   94355
# 2      202009  1호선  246990
# 3      202009  1호선   92148
# 4      202009  1호선   50389
# ...       ...  ...     ...
# 46677  201501  9호선   87864
# 46678  201501  9호선   26443
# 46679  201501  9호선  260917
# 46680  201501  9호선  100670
# 46681  201501  9호선  864989
#
# [46682 rows x 3 columns]

# %%
first.loc[:,'무임승차인원'] = df['무임승차인원'].astype(float)
first.dtypes
# Out:
# C:\Users\sang9\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 사용월        object
# 호선명        object
# 무임승차인원    float64
# dtype: object

# %%
first=first[first['호선명'].str.contains('1')]
first
# Out:
#           사용월  호선명     무임승차인원
# 0      202009  1호선   137054.0
# 1      202009  1호선    94355.0
# 2      202009  1호선   246990.0
# 3      202009  1호선    92148.0
# 4      202009  1호선    50389.0
# ...       ...  ...        ...
# 46385  201501  1호선  1288680.0
# 46386  201501  1호선   819933.0
# 46387  201501  1호선   599790.0
# 46388  201501  1호선   390926.0
# 46389  201501  1호선   363032.0
#
# [1827 rows x 3 columns]

# %%
ninfirst=first[first['사용월'].str.contains('2019')]
ninfirst
# Out:
#           사용월       호선명    무임승차인원
# 5385   201912       1호선  330880.0
# 5386   201912       1호선  412567.0
# 5387   201912       1호선  289976.0
# 5388   201912       1호선  150023.0
# 5389   201912       1호선  321873.0
# ...       ...       ...       ...
# 18989  201901  공항철도 1호선   18332.0
# 18990  201901  공항철도 1호선   32280.0
# 18991  201901  공항철도 1호선    9921.0
# 18992  201901  공항철도 1호선   34330.0
# 18993  201901  공항철도 1호선    8364.0
#
# [552 rows x 3 columns]

# %%
fninm=ninfirst['무임승차인원']
fninm.mean()
# Out:
# 106041.89855072464

# %%
eigfirst=first[first['사용월'].str.contains('2018')]
eigfirst
# Out:
#           사용월       호선명    무임승차인원
# 19114  201812       1호선  272479.0
# 19115  201812       1호선  123951.0
# 19116  201812       1호선  145104.0
# 19117  201812       1호선  227511.0
# 19118  201812       1호선  169334.0
# ...       ...       ...       ...
# 26657  201801  공항철도 1호선   21040.0
# 26658  201801  공항철도 1호선   38551.0
# 26659  201801  공항철도 1호선   15933.0
# 26660  201801  공항철도 1호선    8396.0
# 26661  201801  공항철도 1호선   15941.0
#
# [303 rows x 3 columns]

# %%
feigm=eigfirst['무임승차인원']
feigm.mean()
# Out:
# 105123.21122112211

# %%
sevfirst=first[first['사용월'].str.contains('2017')]
sevfirst
# Out:
#           사용월       호선명    무임승차인원
# 26780  201712       1호선  211349.0
# 26781  201712       1호선  134444.0
# 26782  201712       1호선  166079.0
# 26783  201712       1호선  381909.0
# 26784  201712       1호선  266374.0
# ...       ...       ...       ...
# 33560  201701  공항철도 1호선   20662.0
# 33561  201701  공항철도 1호선   21418.0
# 33562  201701  공항철도 1호선    5562.0
# 33563  201701  공항철도 1호선    7231.0
# 33564  201701  공항철도 1호선   19767.0
#
# [264 rows x 3 columns]

# %%
sevfirst.loc[:,'무임승차인원'] = df['무임승차인원'].astype(float)
sevfirst.dtypes
# Out:
# C:\Users\sang9\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 사용월        object
# 호선명        object
# 무임승차인원    float64
# dtype: object

# %%
fsevm=sevfirst['무임승차인원']
fsevm.mean()
# Out:
# 109486.0303030303

# %%
sixfirst=first[first['사용월'].str.contains('2016')]
sixfirst
# Out:
#           사용월       호선명    무임승차인원
# 33672  201612       1호선  382069.0
# 33673  201612       1호선  126355.0
# 33674  201612       1호선  140426.0
# 33675  201612       1호선  135180.0
# 33676  201612       1호선  226036.0
# ...       ...       ...       ...
# 41428  201601  공항철도 1호선   39209.0
# 41429  201601  공항철도 1호선    7684.0
# 41430  201601  공항철도 1호선   26241.0
# 41431  201601  공항철도 1호선   28637.0
# 41432  201601  공항철도 1호선    7528.0
#
# [306 rows x 3 columns]

# %%
fsixm=sixfirst['무임승차인원']
fsixm.mean()
# Out:
# 108767.64052287582

# %%
fivfirst=first[first['사용월'].str.contains('2015')]
fivfirst
# Out:
#           사용월  호선명     무임승차인원
# 41534  201512  1호선   102259.0
# 41535  201512  1호선   235606.0
# 41536  201512  1호선   169895.0
# 41537  201512  1호선   402176.0
# 41538  201512  1호선   133923.0
# ...       ...  ...        ...
# 46385  201501  1호선  1288680.0
# 46386  201501  1호선   819933.0
# 46387  201501  1호선   599790.0
# 46388  201501  1호선   390926.0
# 46389  201501  1호선   363032.0
#
# [186 rows x 3 columns]

# %%
twfirst=first[first['사용월'].str.contains('2020')]
twfirst
# Out:
#          사용월       호선명    무임승차인원
# 0     202009       1호선  137054.0
# 1     202009       1호선   94355.0
# 2     202009       1호선  246990.0
# 3     202009       1호선   92148.0
# 4     202009       1호선   50389.0
# ...      ...       ...       ...
# 5261  202001  공항철도 1호선   22901.0
# 5262  202001  공항철도 1호선   16893.0
# 5263  202001  공항철도 1호선   10811.0
# 5264  202001  공항철도 1호선   20925.0
# 5265  202001  공항철도 1호선    8024.0
#
# [216 rows x 3 columns]

# %%
ftwm=twfirst['무임승차인원']
ftwm.mean()
# Out:
# 74007.79629629629

# %%
fivfirst.loc[:,'무임승차인원'] = df['무임승차인원'].astype(float)
fivfirst.dtypes
# Out:
# C:\Users\sang9\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 사용월        object
# 호선명        object
# 무임승차인원    float64
# dtype: object

# %%
ffivm=fivfirst['무임승차인원']
ffivm.mean()
# Out:
# 446769.9516129032

# %%
mg=pd.concat([fivfirst,sixfirst,sevfirst,eigfirst,ninfirst],axis=1)
mg
# Out:
#           사용월  호선명     무임승차인원  사용월  호선명  무임승차인원  사용월  호선명  무임승차인원  사용월  호선명  \
# 5385      NaN  NaN        NaN  NaN  NaN     NaN  NaN  NaN     NaN  NaN  NaN
# 5386      NaN  NaN        NaN  NaN  NaN     NaN  NaN  NaN     NaN  NaN  NaN
# 5387      NaN  NaN        NaN  NaN  NaN     NaN  NaN  NaN     NaN  NaN  NaN
# 5388      NaN  NaN        NaN  NaN  NaN     NaN  NaN  NaN     NaN  NaN  NaN
# 5389      NaN  NaN        NaN  NaN  NaN     NaN  NaN  NaN     NaN  NaN  NaN
# ...       ...  ...        ...  ...  ...     ...  ...  ...     ...  ...  ...
# 46385  201501  1호선  1288680.0  NaN  NaN     NaN  NaN  NaN     NaN  NaN  NaN
# 46386  201501  1호선   819933.0  NaN  NaN     NaN  NaN  NaN     NaN  NaN  NaN
# 46387  201501  1호선   599790.0  NaN  NaN     NaN  NaN  NaN     NaN  NaN  NaN
# 46388  201501  1호선   390926.0  NaN  NaN     NaN  NaN  NaN     NaN  NaN  NaN
# 46389  201501  1호선   363032.0  NaN  NaN     NaN  NaN  NaN     NaN  NaN  NaN
#
#        무임승차인원     사용월  호선명    무임승차인원
# ...

# %%
mg.reset_index()
# Out:
#       index     사용월  호선명     무임승차인원  사용월  호선명  무임승차인원  사용월  호선명  무임승차인원  사용월  \
# 0      5385     NaN  NaN        NaN  NaN  NaN     NaN  NaN  NaN     NaN  NaN
# 1      5386     NaN  NaN        NaN  NaN  NaN     NaN  NaN  NaN     NaN  NaN
# 2      5387     NaN  NaN        NaN  NaN  NaN     NaN  NaN  NaN     NaN  NaN
# 3      5388     NaN  NaN        NaN  NaN  NaN     NaN  NaN  NaN     NaN  NaN
# 4      5389     NaN  NaN        NaN  NaN  NaN     NaN  NaN  NaN     NaN  NaN
# ...     ...     ...  ...        ...  ...  ...     ...  ...  ...     ...  ...
# 1606  46385  201501  1호선  1288680.0  NaN  NaN     NaN  NaN  NaN     NaN  NaN
# 1607  46386  201501  1호선   819933.0  NaN  NaN     NaN  NaN  NaN     NaN  NaN
# 1608  46387  201501  1호선   599790.0  NaN  NaN     NaN  NaN  NaN     NaN  NaN
# 1609  46388  201501  1호선   390926.0  NaN  NaN     NaN  NaN  NaN     NaN  NaN
# 1610  46389  201501  1호선   363032.0  NaN  NaN     NaN  NaN  NaN     NaN  NaN
#
#       호선명  무임승차인원     사용월  호선명    무임승차인원
# ...

# %%
muimfirst=pd.DataFrame(data=[['2015',446769],['2016',108767],['2017',109486],
                       ['2018',105123],['2019',106041],['2020',74007]],index=['1','2','3','4','5','6'],
                columns=['년도','무임 승차 수 '])
muimfirst
# Out:
#      년도  무임 승차 수
# 1  2015    446769
# 2  2016    108767
# 3  2017    109486
# 4  2018    105123
# 5  2019    106041
# 6  2020     74007

# %%
plt.figure(figsize=(12,8))
plt.plot(muimfirst['년도'],muimfirst['무임 승차 수 '])
plt.xticks(rotation=45, size=20)
plt.yticks(size=20)
plt.xlabel('년도',size=20)
plt.ylabel('무임 승차 수',size=20)
plt.title('2015-2019 1호선 무임 승차 수 ',size=30)
plt.grid(alpha=0.5)

# %%
noneco=df[df['사용월'].str.contains('202003|202004|202005|202006|202007|202008|202009')]
noneco
# Out:
#          사용월  호선명 지하철역  유임승차인원  무임승차인원  유임하차인원  무임하차인원      작업일자
# 0     202009  1호선  서울역  724320  137054  711203  128369  20201003
# 1     202009  1호선  동대문  184244   94355  184462   95369  20201003
# 2     202009  1호선  제기동  202713  246990  199630  268967  20201003
# 3     202009  1호선  신설동  226849   92148  227364   88012  20201003
# 4     202009  1호선   시청  376545   50389  376445   47503  20201003
# ...      ...  ...  ...     ...     ...     ...     ...       ...
# 4186  202003  중앙선   회기  407944   75519  388315   74372  20200403
# 4187  202003  중앙선   용문   19490   17739   19766   17869  20200403
# 4188  202003  중앙선   도농  165846   36005  149490   35167  20200403
# 4189  202003  중앙선   양원   19587   10293   19797   10385  20200403
# 4190  202003  중앙선  운길산   14334    7357   12589    7372  20200403
#
# [4191 rows x 8 columns]

# %%
noneco1=noneco['유임승차인원']
noneco1
# Out:
# 0       724320
# 1       184244
# 2       202713
# 3       226849
# 4       376545
#          ...
# 4186    407944
# 4187     19490
# 4188    165846
# 4189     19587
# 4190     14334
# Name: 유임승차인원, Length: 4191, dtype: int64

# %%
co=df[df['사용월'].str.contains('201903|201904|201905|201906|201907|201908|201909')]
co
# Out:
#           사용월  호선명  지하철역  유임승차인원  무임승차인원  유임하차인원  무임하차인원      작업일자
# 7177   201909  1호선    시청  618215  104482  628580  105584  20191003
# 7178   201909  1호선   제기동  264818  332466  256270  356572  20191003
# 7179   201909  1호선  종로3가  587524  357984  548967  334959  20191003
# 7180   201909  1호선   동대문  306897  128585  347606  133065  20191003
# 7181   201909  1호선   신설동  340193  117901  332610  112038  20191003
# ...       ...  ...   ...     ...     ...     ...     ...       ...
# 17913  201903  중앙선    아신   16907    6194   16868    5959  20190403
# 17914  201903  중앙선    망우  186168   74066  180366   75312  20190403
# 17915  201903  중앙선    구리  359118   92556  374540   93547  20190403
# 17916  201903  중앙선    원덕    7138    6392    6801    6115  20190403
# 17917  201903  중앙선    용문   39612   40076   39162   39586  20190403
#
# [10741 rows x 8 columns]

# %%
co1=co['유임승차인원']
co1
# Out:
# 7177     618215
# 7178     264818
# 7179     587524
# 7180     306897
# 7181     340193
#           ...
# 17913     16907
# 17914    186168
# 17915    359118
# 17916      7138
# 17917     39612
# Name: 유임승차인원, Length: 10741, dtype: int64

# %%
co1.dtype
# Out:
# dtype('int64')

# %%
result19=[]
result19 = 0

for i in co1:
    result19 += int(i)

print("합계 = ", result19)
result19
# Out:
# 합계 =  3382158478
# 3382158478

# %%
result20=[]
result20= 0

for i in noneco1:
    result20 += int(i)

print("합계 = ", result20)
result20
# Out:
# 합계 =  931506662
# 931506662

# %%
corona=pd.DataFrame(data=[['2019',3382158478],['2020',931506662]],index=['1','2'],
                columns=['2019','2020'])
corona
# Out:
#    2019        2020
# 1  2019  3382158478
# 2  2020   931506662

# %%
plt.figure(figsize=(12,8))
plt.plot(corona['2019'],corona['2020'])
plt.xticks(rotation=45, size=20)
plt.yticks(size=20)
plt.xlabel('년도',size=20)
plt.ylabel('유임 승차 수',size=20)
plt.title('코로나 사태 전 2019년 대비 2020 유임 승차 수의 동향 ',size=20)
plt.grid(alpha=0.5)
