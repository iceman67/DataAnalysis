# %%
import numpy as np
import pandas as pd
 
df = pd.read_csv('movie 01-03.csv',names=('Date', 'Value'),parse_dates=[0],skiprows = 1)
# Out:
#          Date    Value
# 0  2020-01-01  1309913
# 1  2020-01-02   378801
# 2  2020-01-03   379629
# 3  2020-01-04   765968
# 4  2020-01-05   653543
# 5  2020-01-06   231223
# 6  2020-01-07   231828
# 7  2020-01-08   331306
# 8  2020-01-09   283190
# 9  2020-01-10   321578
# 10 2020-01-11   724229
# 11 2020-01-12   650394
# 12 2020-01-13   195502
# 13 2020-01-14   187295
# 14 2020-01-15   274067
# 15 2020-01-16   243672
# 16 2020-01-17   269688
# 17 2020-01-18   594621
# 18 2020-01-19   529614
# 19 2020-01-20   173852
# 20 2020-01-21   165941
# 21 2020-01-22   448088
# 22 2020-01-23   598784
# 23 2020-01-24   967143
# 24 2020-01-25  1251581
# 25 2020-01-26  1428441
# 26 2020-01-27  1200041
# 27 2020-01-28   363504
# 28 2020-01-29   440995
# 29 2020-01-30   244689
# ..        ...      ...
# 61 2020-03-02    59907
# 62 2020-03-03    56646
# 63 2020-03-04    57602
# 64 2020-03-05    53500
# 65 2020-03-06    56969
# 66 2020-03-07   109044
# 67 2020-03-08    93523
# 68 2020-03-09    41129
# ...

# %%
df.head()
# Out:
#         Date    Value
# 0 2020-01-01  1309913
# 1 2020-01-02   378801
# 2 2020-01-03   379629
# 3 2020-01-04   765968
# 4 2020-01-05   653543

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Date'], df['Value'], 'x--')
plt.rcParams["figure.figsize"] = (30,5)
plt.ylabel('# of boxholder')
plt.xlabel('Date')
plt.show()
